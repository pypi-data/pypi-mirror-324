# %%
import pandas as pd

# %%
files_train_df = pd.read_csv("_data/files_train.csv")

# %%
files_train_df
# Out:
#                                   db_path  \
# 0        _data/dbs/0XDE57/SpaceProject.db
# 1        _data/dbs/0XDE57/SpaceProject.db
# 2        _data/dbs/0XDE57/SpaceProject.db
# 3        _data/dbs/0XDE57/SpaceProject.db
# 4        _data/dbs/0XDE57/SpaceProject.db
# ...                                   ...
# 1978066          _data/dbs/zzzzbw/Fame.db
# 1978067          _data/dbs/zzzzbw/Fame.db
# 1978068          _data/dbs/zzzzbw/Fame.db
# 1978069          _data/dbs/zzzzbw/Fame.db
# 1978070          _data/dbs/zzzzbw/Fame.db
#
#                                                   filename  loc  lloc  \
# 0              core/src/com/spaceproject/SpaceProject.java   54    39
# 1        core/src/com/spaceproject/components/AICompone...   29    19
# 2        core/src/com/spaceproject/components/AISpawnCo...   17     9
# 3        core/src/com/spaceproject/components/AsteroidB...   32    10
# 4        core/src/com/spaceproject/components/AsteroidC...   98    23
# ...

# %%
files_train_df[~files_train_df["is_ldl"]]
# Out:
#                                   db_path  \
# 0        _data/dbs/0XDE57/SpaceProject.db
# 1        _data/dbs/0XDE57/SpaceProject.db
# 2        _data/dbs/0XDE57/SpaceProject.db
# 3        _data/dbs/0XDE57/SpaceProject.db
# 4        _data/dbs/0XDE57/SpaceProject.db
# ...                                   ...
# 1978065          _data/dbs/zzzzbw/Fame.db
# 1978066          _data/dbs/zzzzbw/Fame.db
# 1978068          _data/dbs/zzzzbw/Fame.db
# 1978069          _data/dbs/zzzzbw/Fame.db
# 1978070          _data/dbs/zzzzbw/Fame.db
#
#                                                   filename  loc  lloc  \
# 0              core/src/com/spaceproject/SpaceProject.java   54    39
# 1        core/src/com/spaceproject/components/AICompone...   29    19
# 2        core/src/com/spaceproject/components/AISpawnCo...   17     9
# 3        core/src/com/spaceproject/components/AsteroidB...   32    10
# 4        core/src/com/spaceproject/components/AsteroidC...   98    23
# ...
