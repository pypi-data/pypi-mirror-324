# %% [markdown]
# # Q-Score

# %%
# %load_ext autoreload
# %autoreload 2

from iqm.benchmarks.optimization.qscore import *
import random
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Choose (or define) a backend

# %%
backend = "fakeadonis"
#backend = "fakeapollo"
#backend = "garnet"
#backend = "deneb"
#backend = "pyrite"

# %% [markdown]
# ## Set IQM Token if using Resonance.

# %%
import os
os.environ["IQM_TOKEN"] = "XXXXXXXXXXXXXX"

# %% [markdown]
# ## Qscore Configuration

# %%
EXAMPLE_QSCORE = QScoreConfiguration(
    num_instances = 100,
    num_qaoa_layers= 1,
    shots = 20_000,
    calset_id=None, # calibration set ID, default is None
    min_num_nodes =  2,
    max_num_nodes = 5,
    use_virtual_node = True,
    use_classically_optimized_angles = True,
    choose_qubits_routine = "custom",
    custom_qubits_array=[
                    [2, 0],
                    [2, 0, 1],
                    [2, 0, 1, 3],
                    [2, 0, 1, 3, 4]],
    seed = random.randint(1, 999999),
    )

# %% [markdown]
# ## Run the experiment

# %%
benchmark_qscore = QScoreBenchmark(backend, EXAMPLE_QSCORE)
run0_qscore = benchmark_qscore.run()

# %% [markdown]
# ## Perform Analysis

# %%
result0_qscore = benchmark_qscore.analyze()
# Out:
# 2025-01-10 11:11:50,492 - iqm.benchmarks.logging_config - INFO - Q-Score = 2 passed with approximation ratio (Beta) 0.6753; Avg MaxCut size: 0.5900
# 2025-01-10 11:11:51,246 - iqm.benchmarks.logging_config - INFO - Q-Score = 3 passed with approximation ratio (Beta) 0.7632; Avg MaxCut size: 1.4559
# 2025-01-10 11:11:52,302 - iqm.benchmarks.logging_config - INFO - Q-Score = 4 passed with approximation ratio (Beta) 0.7302; Avg MaxCut size: 2.5398
# 2025-01-10 11:11:53,675 - iqm.benchmarks.logging_config - INFO - Q-Score = 5 passed with approximation ratio (Beta) 0.5397; Avg MaxCut size: 3.5741

# %%
result0_qscore.observations
# Out:
# [BenchmarkObservation(name='approximation_ratio', value=0.6753267011332195, identifier=BenchmarkObservationIdentifier(qubit_indices=2), uncertainty=0.09818278368319852),
#  BenchmarkObservation(name='is_succesful', value='True', identifier=BenchmarkObservationIdentifier(qubit_indices=2), uncertainty=None),
#  BenchmarkObservation(name='Qscore_result', value=2, identifier=BenchmarkObservationIdentifier(qubit_indices=2), uncertainty=None),
#  BenchmarkObservation(name='approximation_ratio', value=0.7632430005250532, identifier=BenchmarkObservationIdentifier(qubit_indices=3), uncertainty=0.06217576573542597),
#  BenchmarkObservation(name='is_succesful', value='True', identifier=BenchmarkObservationIdentifier(qubit_indices=3), uncertainty=None),
#  BenchmarkObservation(name='Qscore_result', value=3, identifier=BenchmarkObservationIdentifier(qubit_indices=3), uncertainty=None),
#  BenchmarkObservation(name='approximation_ratio', value=0.7302089185393258, identifier=BenchmarkObservationIdentifier(qubit_indices=4), uncertainty=0.03519230997204089),
#  BenchmarkObservation(name='is_succesful', value='True', identifier=BenchmarkObservationIdentifier(qubit_indices=4), uncertainty=None),
#  BenchmarkObservation(name='Qscore_result', value=4, identifier=BenchmarkObservationIdentifier(qubit_indices=4), uncertainty=None),
#  BenchmarkObservation(name='approximation_ratio', value=0.5397277675240996, identifier=BenchmarkObservationIdentifier(qubit_indices=5), uncertainty=0.034709059407279114),
#  BenchmarkObservation(name='is_succesful', value='True', identifier=BenchmarkObservationIdentifier(qubit_indices=5), uncertainty=None),
#  BenchmarkObservation(name='Qscore_result', value=5, identifier=BenchmarkObservationIdentifier(qubit_indices=5), uncertainty=None)]

# %%
result0_qscore.plot_all()
